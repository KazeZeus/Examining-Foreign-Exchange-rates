# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import scipy as sc

# %%
df = pd.read_csv("train.csv")

# %%
df.head()
# Out:
#     Japan  India   China  Australia        date
# 0  101.70  43.55  8.2798     1.5172  2000-01-03
# 1  103.09  43.55  8.2799     1.5239  2000-01-04
# 2  103.77  43.55  8.2798     1.5267  2000-01-05
# 3  105.19  43.55  8.2797     1.5291  2000-01-06
# 4  105.17  43.55  8.2794     1.5272  2000-01-07

# %%
df.shape
# Out:
# (5018, 5)

# %%
df.dtypes
# Out:
# Japan        float64
# India        float64
# China        float64
# Australia    float64
# date          object
# dtype: object

# %%
df.plot.line('Japan')

# %% [markdown]
# LISTING ALL INDO_PACIFIC COUNTRIES

# %%
df.plot()

# %% [markdown]
# Japan Is Our Target

# %%
df['Japan'].plot()

# %%
df.plot.scatter('date', 'Japan')

# %% [markdown]
# as we can see Exchange rate of japan is relatable with time
